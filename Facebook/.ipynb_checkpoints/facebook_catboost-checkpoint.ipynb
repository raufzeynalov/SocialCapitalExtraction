# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), '..'))

# %%
# Load modules
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import matplotlib
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import KFold   
# Load pandas
import pandas as pd

# Load numpy
import numpy as np

# Set random seed
np.random.seed(0)

#  Plotting imports
import seaborn as sns                                     # Python graphing library
import matplotlib.pyplot as plt

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from sklearn.model_selection import cross_val_score

# %%
# Create an object called iris with the iris data
preprocessed_data = pd.read_pickle('./data/preprocesed_data.pd')

# Create a dataframe with the four feature variables
df = pd.DataFrame(preprocessed_data)

# View the top 5 rows
df
# Out:
#             score  user_friends_num  user_likes_per_post  \
# 6        0.438784              1110             4.590164
# 45       0.570811              1742            22.521390
# 124      0.622349               504            10.121622
# 129      0.645261               508            12.406250
# 285      0.200391              2084             0.936170
# 299      0.471931               476             2.612903
# 321      0.338533              1098             1.871166
# 466      0.383820               183             0.455696
# 469      0.585081              1612            23.544118
# 472      0.434106               585             2.321782
# 473      0.396846               996             2.852113
# 474      0.414482               891             2.980952
# 475      0.469024               557             2.988372
# 476      0.304716               537             0.674292
# 477      0.287751               725             0.762712
# 479      0.303272               470             0.569444
# 481      0.368096               743             1.647059
# 482      0.494076               489             3.256757
# 485      0.376573               922             2.205882
# 489      0.455144              1352             6.434783
# 491      0.510589               767             5.905172
# 496      0.028096               198             0.000000
# 500      0.202303               783             0.359712
# 502      0.383836               471             1.196262
# 505      0.338968               396             0.676157
# 506      0.310708               844             1.116505
# 509      0.506240               317             2.346457
# 510      0.503915               970             7.057823
# 512      0.201708               671             0.250000
# 513      0.417874               547             1.886646
# ...           ...               ...                  ...
# 3225696  0.324647                51             0.000000
# 3234718  0.350987               729             1.385827
# 3261244  0.490075               811             5.235023
# 3288536  0.550558                69             0.625000
# 3290375  0.340265              1154             2.002012
# 3326995  0.636299               125             2.827848
# 3331371  0.378623              2067             5.026316
# 3341858  0.579476               232             3.217949
# 3372547  0.580267               317             4.333333
# 3385819  0.566439               370             4.597938
# 3409711  0.379079               562             1.374384
# 3423345  0.447772               631             2.816327
# 3479273  0.592709               336             5.226667
# 3541562  0.507145               167             1.222222
# 3541563  0.501394               213             1.482759
# 3551281  0.170700               663             0.218845
# 3631899  0.273734              1272             1.193939
# 3655677  0.464548               871             4.500000
# 3655680  0.447079               772             3.435244
# 3724428  0.462882               483             2.450000
# 3780134  0.503937               790             5.744000
# 3805411  0.487944                84             0.530184
# 3805421  0.593460               309             4.800000
# 3863374  0.177543              1551             0.555944
# 3939006  0.201356              1131             0.521277
# 3997089  0.661160               395            11.026316
# 4051850  0.463361               585             2.928571
# 4051851  0.641142              1031            24.317789
# 4051853  0.468198               341             1.811765
# 4115690  0.160725              4213             1.255556
#
#          user_friends_per_post  user_media_to_all_normal_ratio  \
# 6                     9.098361                        0.876033
# 45                    4.657754                        0.583333
# 124                   2.270270                        0.627273
# 129                   2.645833                        0.407407
# 285                  44.340426                        0.977778
# 299                   7.677419                        0.852459
# 321                   6.736196                        0.936709
# 3423345               0.0                           0.000000
# 3479273               0.0                           0.000000
# 3541562               0.0                           0.000000
# 3541563               0.0                           0.000000
# 3551281               0.0                           0.000000
# 3631899               0.0                           0.000000
# 3655677               0.0                           0.000000
# 3655680               0.0                           0.000000
# 3724428               0.0                           0.000000
# 3780134               0.0                           0.000000
# 3805411               0.0                           0.000000
# 3805421               0.0                           0.000000
# 3863374               0.0                           0.000000
# 3939006               0.0                           0.000000
# 3997089               0.0                           0.000000
# 4051850               0.0                           0.000000
# 4051851               0.0                           0.000000
# 4051853               0.0                           0.000000
# 4115690               0.0                           0.000000
#
#          mentions_per_friend  own_mentions_per_friend
# 6                   0.000000                 0.000000
# 45                  0.005741                 0.063720
# 124                 0.017857                 0.162698
# 129                 0.009843                 0.062992
# 285                 0.000000                 0.000000
# 299                 0.000000                 0.000000
# 321                 0.000000                 0.000000
# 466                 0.000000                 0.000000
# 469                 0.006203                 0.006824
# 472                 0.005128                 0.018803
# 473                 0.005020                 0.005020
# 474                 0.001122                 0.075196
# 475                 0.012567                 0.007181
# 476                 0.018622                 0.016760
# 477                 0.000000                 0.000000
# 479                 0.000000                 0.000000
# 481                 0.000000                 0.000000
# 482                 0.000000                 0.000000
# 485                 0.000000                 0.000000
# 489                 0.000000                 0.000000
# 491                 0.001304                 0.013038
# 496                 0.000000                 0.000000
# 500                 0.000000                 0.000000
# 502                 0.000000                 0.000000
# 505                 0.000000                 0.000000
# 506                 0.000000                 0.000000
# 509                 0.000000                 0.000000
# 510                 0.000000                 0.000000
# 512                 0.000000                 0.000000
# 513                 0.005484                 0.032907
# ...                      ...                      ...
# 3225696             0.000000                 0.000000
# 3234718             0.000000                 0.000000
# 3261244             0.000000                 0.000000
# 3288536             0.000000                 0.000000
# 3290375             0.000000                 0.000000
# 3326995             0.000000                 0.000000
# 3331371             0.000000                 0.000000
# 3341858             0.000000                 0.000000
# 3372547             0.000000                 0.000000
# 3385819             0.000000                 0.000000
# 3409711             0.000000                 0.000000
# 3423345             0.000000                 0.000000
# 3479273             0.000000                 0.000000
# 3541562             0.000000                 0.000000
# 3541563             0.000000                 0.000000
# 3551281             0.000000                 0.000000
# 3631899             0.000000                 0.000000
# 3655677             0.000000                 0.000000
# 3655680             0.000000                 0.000000
# 3724428             0.000000                 0.000000
# 3780134             0.000000                 0.000000
# 3805411             0.000000                 0.000000
# 3805421             0.000000                 0.000000
# 3863374             0.000000                 0.000000
# 3939006             0.000000                 0.000000
# 3997089             0.000000                 0.000000
# 4051850             0.000000                 0.000000
# 4051851             0.000000                 0.000000
# 4051853             0.000000                 0.000000
# 4115690             0.000000                 0.000000
#
# [11629 rows x 24 columns]

# %%
# Create two new dataframes, one with the training rows, one with the test rows
train, valid=train_test_split(df, test_size=0.2, random_state=0)

# %%
# Show the number of observations for the test and training dataframes
print('Number of observations in the training data:', len(train))
print('Number of observations in the test data:',len(valid))
# Out:
# Number of observations in the training data: 9303
# Number of observations in the test data: 2326

# %%
train=pd.DataFrame(train,columns=df.columns)
valid=pd.DataFrame(valid,columns=df.columns)
X_train=train.drop(['score'],axis=1)
Y_train=train['score']
X_valid=valid.drop(['score'],axis=1)
Y_valid=valid['score']

# %%
def acc_model(params):
    clf = RandomForestRegressor(**params)
    return cross_val_score(clf, X_train, Y_train).mean()

param_space = {
        'estimate__random_state': hp.choice('estimate__random_state', [0]),
        'estimate__oob_score': hp.choice('estimate__oob_score', [True]),
        'estimate__max_features': hp.uniform('estimate__max_features', 0, 1.),
        'estimate__n_estimators': hp.choice('estimate__n_estimators', range(1, 3000 + 1)),
        'estimate__min_samples_leaf': hp.choice('estimate__min_samples_leaf', range(1, 100 + 1)),
        'estimate__scale': hp.choice('estimate__scale', [0, 1.]),
        'estimate__normalize': hp.choice('estimate__normalize', [0, 1.])}

best = 0

def custom_r2(estimator, X_test, y_test):
    predictions = estimator.predict(X_test)
    return r2_score(y_test, predictions)

def f(params):
    shuffle = KFold(3, shuffle=True)
    score = cross_val_score(X_train, Y_train,
                                cv=shuffle, scoring='neg_mean_squared_error', n_jobs=1)

    r2 = cross_val_score(X_train, Y_train,
                             cv=shuffle, scoring=custom_r2, n_jobs=1)
    result = {
            'loss': sqrt(-score.mean()),
            'r2': r2.mean(),
            'cv_eval_time': time() - start_time,
            'status': STATUS_FAIL if np.isnan(score.mean()) else STATUS_OK,
            'params': params.copy()
        }

trials = Trials()
best_ = fmin(f, param_space, algo=tpe.suggest,
                              max_evals=self.max_evals, trials=trials, verbose=True)

            # save the hyperparameter at each iteration to a csv file
param_values = [x['misc']['vals'] for x in trials.trials]
param_values = [{key: value for key in x for value in x[key]} for x in param_values]
param_values = [space_eval(param_space, x) for x in param_values]
param_df = pd.DataFrame(param_values)
param_df['cv_eval_time'] = [r.get('cv_eval_time') for r in trials.results]
param_df['RMSE'] = trials.losses()
param_df['R^2'] = [r.get('r2') for r in trials.results]
param_df.index.name = 'Iteration'
param_df.to_csv('./outputs/parameters/%s.csv' % self.output_prefix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0eb8b44a6b70> in <module>()
#      35 trials = Trials()
#      36 best_ = fmin(f, param_space, algo=tpe.suggest,
# ---> 37                               max_evals=self.max_evals, trials=trials, verbose=True)
#      38
#      39             # save the hyperparameter at each iteration to a csv file
#
# NameError: name 'self' is not defined

# %%
# Out:
# 236280     0.462698
# 19577      0.461392
# 84396      0.705209
# 1566122    0.402961
# 4027       0.343258
# 602313     0.471329
# 1566141    0.464967
# 161959     0.147570
# 1771888    0.271327
# 121485     0.355757
# 5348       0.400165
# 1197636    0.507947
# 175700     0.370310
# 697527     0.275626
# 48702      0.504124
# 286933     0.452913
# 10261      0.407198
# 196026     0.376703
# 106042     0.113064
# 237530     0.350242
# 286976     0.561769
# 284583     0.274707
# 51872      0.507474
# 583263     0.362811
# 3225696    0.324647
# 208169     0.333195
# 28540      0.411103
# 170496     0.260977
# 5208       0.483135
# 165112     0.345155
#              ...
# 264236     0.469387
# 22082      0.427263
# 23169      0.457358
# 289999     0.330848
# 116042     0.430537
# 124531     0.522656
# 26146      0.456236
# 162683     0.465099
# 210338     0.486815
# 170358     0.592716
# 1287443    0.483143
# 5171       0.345553
# 632985     0.680477
# 42340      0.451571
# 284517     0.356644
# 27939      0.528190
# 799139     0.641569
# 36700      0.486426
# 10393      0.390630
# 59313      0.402241
# 198858     0.429230
# 159459     0.328882
# 89830      0.539911
# 290948     0.403340
# 480324     0.397323
# 116841     0.380991
# 54435      0.566663
# 623190     0.474346
# 1035891    0.509541
# 39371      0.412797
# Name: score, Length: 9303, dtype: float64

# %%
RF2=RandomForestClassifier(max_features=113, n_estimators=498, criterion= 'entropy', max_depth=2,random_state=1)

# %%
    rf = HyperoptModel(train.copy(), test.copy(), '' + 'rf', cv=3)
    hyperopt='--optimize'
    rf.raw_features = []
    rf.pipeline = Pipeline([
        ('prepare_features', FeatureUnion([
            ('user_stats', user_features),
            ('mention_stats', mention_features),
            ('posts_stats', post_features),
            ('comments_stats', comment_features)
        ])),
        ('estimate', CatBoostRegressor(**{'max_features': 0.5304853637778143,
                                              'min_samples_leaf': 1,
                                              'n_estimators': 1657,
                                              'oob_score': True,
                                              'random_state': 0}))
    ])
    for transformer in rf.pipeline.named_steps['prepare_features'].transformer_list:
        rf.raw_features += [t if isinstance(t, basestring) else t[0] for t, _, _ in transformer[1].features]

    rf.space = {
        'estimate__random_state': hp.choice('estimate__random_state', [0]),
        'estimate__oob_score': hp.choice('estimate__oob_score', [True]),

        'estimate__max_features': hp.uniform('estimate__max_features', 0, 1.),
        'estimate__n_estimators': hp.choice('estimate__n_estimators', range(1, 3000 + 1)),
        'estimate__min_samples_leaf': hp.choice('estimate__min_samples_leaf', range(1, 100 + 1)),
        'estimate__scale': hp.choice('estimate__scale', [0, 1.]),
        'estimate__normalize': hp.choice('estimate__normalize', [0, 1.]),
    }

    if hyperopt:
        rf.run(do_lowess=DO_LOWESS)
    else:
        # train with default params
        rf.pipeline.fit(X=rf.X_train, y=rf.y_train)
        rf.model = rf.pipeline
        rf.stats()
        rf.plot_predicted_vs_actual()
        rf.plot_feature_importance()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-f3756e9ba763> in <module>()
#      16 ])
#      17 for transformer in rf.pipeline.named_steps['prepare_features'].transformer_list:
# ---> 18     rf.raw_features += [t if isinstance(t, basestring) else t[0] for t, _, _ in transformer[1].features]
#      19
#      20 rf.space = {
#
# <ipython-input-67-f3756e9ba763> in <listcomp>(.0)
#      16 ])
#      17 for transformer in rf.pipeline.named_steps['prepare_features'].transformer_list:
# ---> 18     rf.raw_features += [t if isinstance(t, basestring) else t[0] for t, _, _ in transformer[1].features]
#      19
#      20 rf.space = {
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
print(regr.feature_importances_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-3227059354cd> in <module>()
# ----> 1 print(regr.feature_importances_)
#
# NameError: name 'regr' is not defined

# %%
# variable importance
importances = regr.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), features[indices])
plt.xlabel('Relative Importance')
plt.show()
