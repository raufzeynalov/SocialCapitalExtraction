# %%
#imports
import numpy as np
import pandas as pd
from hyperopt import hp
from hyperopt.pyll import scope
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPRegressor

import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from models.hyperopt_model import HyperoptModel
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
# read the data
preprocessed_data = pd.read_pickle('../data/preprocessed_science_qualitative.pd')

# Create a dataframe
df = pd.DataFrame(preprocessed_data)

# %%
# Create two new dataframes, one with the training rows, one with the test rows
train, test=train_test_split(df, test_size=0.2, random_state=0)

# %%
# Show the number of observations for the test and training dataframes
print('Number of observations in the training data:', len(train))
print('Number of observations in the test data:',len(test))
# Out:
# Number of observations in the training data: 79342
# Number of observations in the test data: 19836

# %%
    #some parameters
    DO_LOWESS = False
    hyperopt = True
    # Run MLPRegressor with hyperopt optimization
    nn = HyperoptModel(train.copy(), test.copy(),'nn', cv=3, max_evals=100)
    features = list(df)
    features.remove('score')
    nn.raw_features = features

    nn.pipeline = Pipeline([
        ('estimate', MLPRegressor())
    ])
   
    nn.space = {
         'estimate__alpha' : hp.uniform('estimate__alpha', 0.001, 1),
         'estimate__activation' : hp.choice('estimate__activation', ['relu']), #'identity', 'logistic', 'tanh', 'relu'
         #'estimate__learning_rate' : hp.choice('estimate__learning_rate', ['constant', 'invscaling', 'adaptive']),
         'estimate__hidden_layer_sizes' : scope.int(hp.uniform('estimate__hidden_layer_sizes', 1, 100)),
         'estimate__solver' : hp.choice('estimate__solver', ['adam']), #'lbfgs', 'sgd',
         #'estimate__max_iter' : scope.int(hp.uniform('estimate__max_iter', 500, 1000))
    }

    if hyperopt:
        nn.run(do_lowess=DO_LOWESS)
    else:
        # train with default params
        nn.pipeline.fit(X=nn.X_train, y=nn.y_train)
        nn.model = cat.pipeline
        nn.stats()
        nn.plot_predicted_vs_actual(do_lowess=DO_LOWESS)
        nn.plot_feature_importance()
        nn.qq_plot()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked',)).History will not be written to the database.
# Performing parameters optimization...
# [1/100]	cv_eval_time=139.68 sec	RMSE=0.105045	R^2=0.376545
# [2/100]	cv_eval_time=156.27 sec	RMSE=0.106381	R^2=0.358552
# [3/100]	cv_eval_time=101.43 sec	RMSE=0.108255	R^2=0.340352
# [4/100]	cv_eval_time=102.77 sec	RMSE=0.107458	R^2=0.341776
# [5/100]	cv_eval_time=67.03 sec	RMSE=0.103133	R^2=0.390515
# [6/100]	cv_eval_time=63.34 sec	RMSE=0.100090	R^2=0.430185
# [7/100]	cv_eval_time=55.99 sec	RMSE=0.103112	R^2=0.395860
# [8/100]	cv_eval_time=37.41 sec	RMSE=0.103513	R^2=0.390619
# [9/100]	cv_eval_time=36.63 sec	RMSE=0.107478	R^2=0.345039
# [10/100]	cv_eval_time=37.48 sec	RMSE=0.103797	R^2=0.386538
# [11/100]	cv_eval_time=43.36 sec	RMSE=0.104329	R^2=0.384822
# [12/100]	cv_eval_time=52.80 sec	RMSE=0.106884	R^2=0.355300
# [13/100]	cv_eval_time=40.06 sec	RMSE=0.105778	R^2=0.363738
# [14/100]	cv_eval_time=49.63 sec	RMSE=0.102426	R^2=0.406471
# [15/100]	cv_eval_time=34.37 sec	RMSE=0.104864	R^2=0.373424
# [16/100]	cv_eval_time=29.67 sec	RMSE=0.106408	R^2=0.355407
# [17/100]	cv_eval_time=34.68 sec	RMSE=0.098692	R^2=0.440850
# [18/100]	cv_eval_time=38.92 sec	RMSE=0.103124	R^2=0.396079
# [19/100]	cv_eval_time=44.73 sec	RMSE=0.097778	R^2=0.449821
# [20/100]	cv_eval_time=36.48 sec	RMSE=0.101545	R^2=0.412626
# [21/100]	cv_eval_time=39.49 sec	RMSE=0.098617	R^2=0.450470
# [22/100]	cv_eval_time=26.48 sec	RMSE=0.097975	R^2=0.449205
# [23/100]	cv_eval_time=34.73 sec	RMSE=0.100118	R^2=0.422760
# [24/100]	cv_eval_time=32.53 sec	RMSE=0.100397	R^2=0.431728
# [25/100]	cv_eval_time=15.41 sec	RMSE=0.098569	R^2=0.416660
# [26/100]	cv_eval_time=25.04 sec	RMSE=0.102186	R^2=0.417584
# [27/100]	cv_eval_time=40.00 sec	RMSE=0.099269	R^2=0.447812
# [28/100]	cv_eval_time=26.35 sec	RMSE=0.107734	R^2=0.340304
# [29/100]	cv_eval_time=28.78 sec	RMSE=0.101764	R^2=0.424166
# [30/100]	cv_eval_time=16.80 sec	RMSE=0.097879	R^2=0.449371
# [31/100]	cv_eval_time=28.93 sec	RMSE=0.102966	R^2=0.402308
# [32/100]	cv_eval_time=25.17 sec	RMSE=0.104728	R^2=0.374218
# [33/100]	cv_eval_time=18.28 sec	RMSE=0.097539	R^2=0.452298
# [34/100]	cv_eval_time=33.39 sec	RMSE=0.099621	R^2=0.433536
# [35/100]	cv_eval_time=32.00 sec	RMSE=0.100769	R^2=0.422041
# [36/100]	cv_eval_time=33.31 sec	RMSE=0.100276	R^2=0.436183
# [37/100]	cv_eval_time=26.89 sec	RMSE=0.102525	R^2=0.392629
# [38/100]	cv_eval_time=25.75 sec	RMSE=0.105323	R^2=0.370514
# [39/100]	cv_eval_time=15.82 sec	RMSE=0.098393	R^2=0.456031
# [40/100]	cv_eval_time=28.33 sec	RMSE=0.101233	R^2=0.424190
# [41/100]	cv_eval_time=20.10 sec	RMSE=0.106487	R^2=0.356666
# [42/100]	cv_eval_time=27.98 sec	RMSE=0.103762	R^2=0.382515
# [43/100]	cv_eval_time=20.32 sec	RMSE=0.107963	R^2=0.338498
# [44/100]	cv_eval_time=27.97 sec	RMSE=0.101549	R^2=0.411677
# [45/100]	cv_eval_time=23.90 sec	RMSE=0.105703	R^2=0.378972
# [46/100]	cv_eval_time=23.71 sec	RMSE=0.103156	R^2=0.401150
# [47/100]	cv_eval_time=28.87 sec	RMSE=0.099896	R^2=0.439466
# [48/100]	cv_eval_time=26.05 sec	RMSE=0.104556	R^2=0.384792
# [49/100]	cv_eval_time=31.92 sec	RMSE=0.101842	R^2=0.409005
# [50/100]	cv_eval_time=16.89 sec	RMSE=0.115840	R^2=0.233484
# [51/100]	cv_eval_time=26.25 sec	RMSE=0.105287	R^2=0.364719
# [52/100]	cv_eval_time=35.05 sec	RMSE=0.098606	R^2=0.449630
# [53/100]	cv_eval_time=25.56 sec	RMSE=0.103489	R^2=0.384228
# [54/100]	cv_eval_time=26.06 sec	RMSE=0.097903	R^2=0.447736
# [55/100]	cv_eval_time=34.17 sec	RMSE=0.100560	R^2=0.421823
# [56/100]	cv_eval_time=30.63 sec	RMSE=0.102099	R^2=0.418583
# [57/100]	cv_eval_time=30.99 sec	RMSE=0.100107	R^2=0.435205
# [58/100]	cv_eval_time=19.98 sec	RMSE=0.107281	R^2=0.347414
# [59/100]	cv_eval_time=22.04 sec	RMSE=0.106188	R^2=0.356886
# [60/100]	cv_eval_time=23.48 sec	RMSE=0.105627	R^2=0.369634
# [61/100]	cv_eval_time=29.74 sec	RMSE=0.100063	R^2=0.433800
# [62/100]	cv_eval_time=23.71 sec	RMSE=0.105042	R^2=0.381347
# [63/100]	cv_eval_time=25.16 sec	RMSE=0.101557	R^2=0.404124
# [64/100]	cv_eval_time=29.26 sec	RMSE=0.103391	R^2=0.401242
# [65/100]	cv_eval_time=16.35 sec	RMSE=0.097616	R^2=0.461116
# [66/100]	cv_eval_time=14.72 sec	RMSE=0.100466	R^2=0.433196
# [67/100]	cv_eval_time=36.78 sec	RMSE=0.098500	R^2=0.432638
# [68/100]	cv_eval_time=28.34 sec	RMSE=0.097524	R^2=0.451636
# [69/100]	cv_eval_time=39.30 sec	RMSE=0.099564	R^2=0.435271
# [70/100]	cv_eval_time=28.84 sec	RMSE=0.097867	R^2=0.462098
# [71/100]	cv_eval_time=34.13 sec	RMSE=0.098686	R^2=0.441811
# [72/100]	cv_eval_time=34.36 sec	RMSE=0.100827	R^2=0.423615
# [73/100]	cv_eval_time=34.00 sec	RMSE=0.101398	R^2=0.413297
# [74/100]	cv_eval_time=40.09 sec	RMSE=0.098673	R^2=0.450440
# [75/100]	cv_eval_time=26.97 sec	RMSE=0.102245	R^2=0.406322
# [76/100]	cv_eval_time=33.91 sec	RMSE=0.100740	R^2=0.423610
# [77/100]	cv_eval_time=35.24 sec	RMSE=0.100124	R^2=0.435827
# [78/100]	cv_eval_time=30.58 sec	RMSE=0.101637	R^2=0.416959
# [79/100]	cv_eval_time=33.15 sec	RMSE=0.098856	R^2=0.444941
# [80/100]	cv_eval_time=35.43 sec	RMSE=0.100464	R^2=0.425774
# [81/100]	cv_eval_time=26.29 sec	RMSE=0.103666	R^2=0.390451
# [82/100]	cv_eval_time=30.71 sec	RMSE=0.098426	R^2=0.448691
# [83/100]	cv_eval_time=29.74 sec	RMSE=0.103262	R^2=0.410426
# [84/100]	cv_eval_time=29.10 sec	RMSE=0.102836	R^2=0.396870
# [85/100]	cv_eval_time=14.08 sec	RMSE=0.098084	R^2=0.454047
# [86/100]	cv_eval_time=35.82 sec	RMSE=0.101159	R^2=0.423058
# [87/100]	cv_eval_time=38.00 sec	RMSE=0.099427	R^2=0.444684
# [88/100]	cv_eval_time=30.99 sec	RMSE=0.101919	R^2=0.407425
# [89/100]	cv_eval_time=33.33 sec	RMSE=0.100684	R^2=0.428287
# [90/100]	cv_eval_time=21.88 sec	RMSE=0.105889	R^2=0.356007
# [91/100]	cv_eval_time=19.73 sec	RMSE=0.107961	R^2=0.351133
# [92/100]	cv_eval_time=30.38 sec	RMSE=0.101355	R^2=0.414376
# [93/100]	cv_eval_time=22.02 sec	RMSE=0.104479	R^2=0.382012
# [94/100]	cv_eval_time=23.42 sec	RMSE=0.103254	R^2=0.389165
# [95/100]	cv_eval_time=23.84 sec	RMSE=0.097449	R^2=0.453391
# [96/100]	cv_eval_time=26.10 sec	RMSE=0.097474	R^2=0.456036
# [97/100]	cv_eval_time=25.68 sec	RMSE=0.097761	R^2=0.453767
# [98/100]	cv_eval_time=21.02 sec	RMSE=0.108731	R^2=0.329998
# [99/100]	cv_eval_time=29.54 sec	RMSE=0.099171	R^2=0.447099
# [100/100]	cv_eval_time=29.94 sec	RMSE=0.099240	R^2=0.438876
#  elapsed time: 57min 11s
#
# Stats (train | test):
# 	R^2 score:		0.4601
# 					0.4603
# 	RMSE:			0.0975
# 					0.0977
# 	Mean error:		0.0742
# 					0.0744
# 	Pearson:		0.6801
# 					0.6797
# 	Spearman:		0.6643
# 					0.6645
# 	KendallTau:		0.4849
# 					0.4853
#
# Best parameters set:
# {'estimate__activation': 'relu',
#  'estimate__alpha': 0.02141321437292044,
#  'estimate__hidden_layer_sizes': 83,
#  'estimate__solver': 'adam'}
#
# Plotting predicted vs. actual ...done
#
# Plotting QQ ...done

# %%
    #some parameters
    DO_LOWESS = False
    hyperopt = True
    # Run MLPRegressor with hyperopt optimization
    nn = HyperoptModel(train.copy(), test.copy(),'nn', cv=3, max_evals=100)
    features = list(df)
    features.remove('score')
    nn.raw_features = features

    nn.pipeline = Pipeline([
        ('estimate', MLPRegressor())
    ])
   
    nn.space = {
         'estimate__alpha' : hp.uniform('estimate__alpha', 0.001, 1),
         'estimate__activation' : hp.choice('estimate__activation', ['logistic']), #'identity', 'logistic', 'tanh', 'relu'
         #'estimate__learning_rate' : hp.choice('estimate__learning_rate', ['constant', 'invscaling', 'adaptive']),
         'estimate__hidden_layer_sizes' : scope.int(hp.uniform('estimate__hidden_layer_sizes', 1, 100)),
         'estimate__solver' : hp.choice('estimate__solver', ['adam']), #'lbfgs', 'sgd',
         #'estimate__max_iter' : scope.int(hp.uniform('estimate__max_iter', 500, 1000))
    }

    if hyperopt:
        nn.run(do_lowess=DO_LOWESS)
    else:
        # train with default params
        nn.pipeline.fit(X=nn.X_train, y=nn.y_train)
        nn.model = cat.pipeline
        nn.stats()
        nn.plot_predicted_vs_actual(do_lowess=DO_LOWESS)
        nn.plot_feature_importance()
        nn.qq_plot()
# Out:
# Performing parameters optimization...
# [1/100]	cv_eval_time=18.28 sec	RMSE=0.110433	R^2=0.305041
# [2/100]	cv_eval_time=14.06 sec	RMSE=0.107366	R^2=0.350907
# [3/100]	cv_eval_time=20.06 sec	RMSE=0.107986	R^2=0.353074
# [4/100]	cv_eval_time=17.67 sec	RMSE=0.110154	R^2=0.314170
# [5/100]	cv_eval_time=13.68 sec	RMSE=0.115596	R^2=0.243995
# [6/100]	cv_eval_time=18.90 sec	RMSE=0.117980	R^2=0.210704
# [7/100]	cv_eval_time=16.51 sec	RMSE=0.119257	R^2=0.203892
# [8/100]	cv_eval_time=18.81 sec	RMSE=0.109696	R^2=0.323276
# [9/100]	cv_eval_time=15.07 sec	RMSE=0.110624	R^2=0.310920
# [10/100]	cv_eval_time=17.22 sec	RMSE=0.115699	R^2=0.228821
# [11/100]	cv_eval_time=15.89 sec	RMSE=0.108477	R^2=0.333583
# [12/100]	cv_eval_time=19.24 sec	RMSE=0.115448	R^2=0.253804
# [13/100]	cv_eval_time=20.89 sec	RMSE=0.110456	R^2=0.311226
# [14/100]	cv_eval_time=16.61 sec	RMSE=0.110086	R^2=0.314192
# [15/100]	cv_eval_time=20.96 sec	RMSE=0.117947	R^2=0.215559
# [16/100]	cv_eval_time=12.06 sec	RMSE=0.119971	R^2=0.171570
# [17/100]	cv_eval_time=25.79 sec	RMSE=0.106109	R^2=0.362982
# [18/100]	cv_eval_time=12.36 sec	RMSE=0.118630	R^2=0.198544
# [19/100]	cv_eval_time=13.05 sec	RMSE=0.113861	R^2=0.262276
# [20/100]	cv_eval_time=15.26 sec	RMSE=0.111018	R^2=0.351182
# [21/100]	cv_eval_time=14.02 sec	RMSE=0.112466	R^2=0.283675
# [22/100]	cv_eval_time=26.45 sec	RMSE=0.107590	R^2=0.347180
# [23/100]	cv_eval_time=20.56 sec	RMSE=0.111375	R^2=0.292599
# [24/100]	cv_eval_time=12.24 sec	RMSE=0.105814	R^2=0.373592
# [25/100]	cv_eval_time=25.17 sec	RMSE=0.105666	R^2=0.369551
# [26/100]	cv_eval_time=15.71 sec	RMSE=0.105573	R^2=0.370076
# [27/100]	cv_eval_time=24.99 sec	RMSE=0.108207	R^2=0.331462
# [28/100]	cv_eval_time=20.43 sec	RMSE=0.111708	R^2=0.298641
# [29/100]	cv_eval_time=16.02 sec	RMSE=0.116885	R^2=0.230247
# [30/100]	cv_eval_time=18.29 sec	RMSE=0.112954	R^2=0.273903
# [31/100]	cv_eval_time=18.74 sec	RMSE=0.107500	R^2=0.338178
# [32/100]	cv_eval_time=18.66 sec	RMSE=0.105422	R^2=0.369555
# [33/100]	cv_eval_time=20.45 sec	RMSE=0.110799	R^2=0.281051
# [34/100]	cv_eval_time=16.71 sec	RMSE=0.107698	R^2=0.340763
# [35/100]	cv_eval_time=18.54 sec	RMSE=0.114603	R^2=0.245604
# [36/100]	cv_eval_time=15.35 sec	RMSE=0.108466	R^2=0.337506
# [37/100]	cv_eval_time=19.02 sec	RMSE=0.118582	R^2=0.205040
# [38/100]	cv_eval_time=23.78 sec	RMSE=0.106633	R^2=0.334563
# [39/100]	cv_eval_time=24.37 sec	RMSE=0.109434	R^2=0.312712
# [40/100]	cv_eval_time=15.36 sec	RMSE=0.112273	R^2=0.281152
# [41/100]	cv_eval_time=19.03 sec	RMSE=0.111461	R^2=0.306616
# [42/100]	cv_eval_time=17.67 sec	RMSE=0.113640	R^2=0.260375
# [43/100]	cv_eval_time=19.91 sec	RMSE=0.104923	R^2=0.373801
# [44/100]	cv_eval_time=22.22 sec	RMSE=0.110468	R^2=0.329841
# [45/100]	cv_eval_time=20.24 sec	RMSE=0.116483	R^2=0.228073
# [46/100]	cv_eval_time=18.67 sec	RMSE=0.113955	R^2=0.252432
# [47/100]	cv_eval_time=25.66 sec	RMSE=0.107780	R^2=0.342065
# [48/100]	cv_eval_time=24.26 sec	RMSE=0.106521	R^2=0.354683
# [49/100]	cv_eval_time=20.65 sec	RMSE=0.109296	R^2=0.318382
# [50/100]	cv_eval_time=21.13 sec	RMSE=0.115530	R^2=0.231503
# [51/100]	cv_eval_time=18.92 sec	RMSE=0.110354	R^2=0.310854
# [52/100]	cv_eval_time=19.67 sec	RMSE=0.117015	R^2=0.222883
# [53/100]	cv_eval_time=23.83 sec	RMSE=0.108758	R^2=0.333718
# [54/100]	cv_eval_time=20.14 sec	RMSE=0.115655	R^2=0.232556
# [55/100]	cv_eval_time=16.47 sec	RMSE=0.112345	R^2=0.284493
# [56/100]	cv_eval_time=18.86 sec	RMSE=0.110478	R^2=0.305508
# [57/100]	cv_eval_time=22.19 sec	RMSE=0.106303	R^2=0.354222
# [58/100]	cv_eval_time=21.53 sec	RMSE=0.106036	R^2=0.367492
# [59/100]	cv_eval_time=26.32 sec	RMSE=0.108423	R^2=0.331852
# [60/100]	cv_eval_time=19.14 sec	RMSE=0.118621	R^2=0.189575
# [61/100]	cv_eval_time=24.31 sec	RMSE=0.107101	R^2=0.340203
# [62/100]	cv_eval_time=20.08 sec	RMSE=0.112324	R^2=0.291761
# [63/100]	cv_eval_time=15.91 sec	RMSE=0.113906	R^2=0.255118
# [64/100]	cv_eval_time=17.31 sec	RMSE=0.117101	R^2=0.232240
# [65/100]	cv_eval_time=19.76 sec	RMSE=0.106093	R^2=0.350585
# [66/100]	cv_eval_time=15.48 sec	RMSE=0.105122	R^2=0.365191
# [67/100]	cv_eval_time=13.85 sec	RMSE=0.105141	R^2=0.369779
# [68/100]	cv_eval_time=15.01 sec	RMSE=0.108600	R^2=0.342795
# [69/100]	cv_eval_time=16.04 sec	RMSE=0.106818	R^2=0.356720
# [70/100]	cv_eval_time=20.27 sec	RMSE=0.106120	R^2=0.363481
# [71/100]	cv_eval_time=16.01 sec	RMSE=0.105794	R^2=0.365938
# [72/100]	cv_eval_time=18.76 sec	RMSE=0.106859	R^2=0.343433
# [73/100]	cv_eval_time=14.66 sec	RMSE=0.110072	R^2=0.313882
# [74/100]	cv_eval_time=17.68 sec	RMSE=0.108732	R^2=0.333702
# [75/100]	cv_eval_time=15.36 sec	RMSE=0.106066	R^2=0.352612
# [76/100]	cv_eval_time=17.70 sec	RMSE=0.111257	R^2=0.292034
# [77/100]	cv_eval_time=14.09 sec	RMSE=0.109003	R^2=0.329034
# [78/100]	cv_eval_time=20.66 sec	RMSE=0.107723	R^2=0.348252
# [79/100]	cv_eval_time=14.36 sec	RMSE=0.105139	R^2=0.373343
# [80/100]	cv_eval_time=16.48 sec	RMSE=0.112959	R^2=0.278617
# [81/100]	cv_eval_time=15.70 sec	RMSE=0.110704	R^2=0.309497
# [82/100]	cv_eval_time=17.57 sec	RMSE=0.108585	R^2=0.338039
# [83/100]	cv_eval_time=13.92 sec	RMSE=0.106651	R^2=0.355960
# [84/100]	cv_eval_time=26.23 sec	RMSE=0.106626	R^2=0.354124
# [85/100]	cv_eval_time=13.81 sec	RMSE=0.112170	R^2=0.276950
# [86/100]	cv_eval_time=20.43 sec	RMSE=0.109292	R^2=0.320992
# [87/100]	cv_eval_time=15.11 sec	RMSE=0.114159	R^2=0.265281
# [88/100]	cv_eval_time=15.78 sec	RMSE=0.114406	R^2=0.253944
# [89/100]	cv_eval_time=12.97 sec	RMSE=0.109621	R^2=0.309983
# [90/100]	cv_eval_time=14.65 sec	RMSE=0.119434	R^2=0.198816
# [91/100]	cv_eval_time=19.42 sec	RMSE=0.112043	R^2=0.293158
# [92/100]	cv_eval_time=21.62 sec	RMSE=0.105976	R^2=0.368187
# [93/100]	cv_eval_time=17.71 sec	RMSE=0.107903	R^2=0.336931
# [94/100]	cv_eval_time=15.29 sec	RMSE=0.110257	R^2=0.313577
# [95/100]	cv_eval_time=17.90 sec	RMSE=0.108201	R^2=0.334129
# [96/100]	cv_eval_time=19.68 sec	RMSE=0.107146	R^2=0.352457
# [97/100]	cv_eval_time=14.10 sec	RMSE=0.114655	R^2=0.244073
# [98/100]	cv_eval_time=18.99 sec	RMSE=0.107238	R^2=0.358774
# [99/100]	cv_eval_time=22.50 sec	RMSE=0.109266	R^2=0.321952
# [100/100]	cv_eval_time=15.58 sec	RMSE=0.118265	R^2=0.220568
#  elapsed time: 30min 38s
#
# Stats (train | test):
# 	R^2 score:		0.3761
# 					0.3812
# 	RMSE:			0.1048
# 					0.1046
# 	Mean error:		0.0814
# 					0.0809
# 	Pearson:		0.6174
# 					0.6206
# 	Spearman:		0.6239
# 					0.6259
# 	KendallTau:		0.4497
# 					0.4520
#
# Best parameters set:
# {'estimate__activation': 'logistic',
#  'estimate__alpha': 0.0027633962489585617,
#  'estimate__hidden_layer_sizes': 94,
#  'estimate__solver': 'adam'}
#
# Plotting predicted vs. actual ...done
#
# Plotting QQ ...done
