# %%
#imports
import numpy as np
import pandas as pd
from hyperopt import hp
from hyperopt.pyll import scope
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPRegressor

import os
import sys
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from models.hyperopt_model import HyperoptModel
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
# read the data
preprocessed_data = pd.read_pickle('../data/preprocessed_twitter_qualitative.pd')

# Create a dataframe
df = pd.DataFrame(preprocessed_data)

# %%
# Create two new dataframes, one with the training rows, one with the test rows
train, test=train_test_split(df, test_size=0.2, random_state=0)

# %%
# Show the number of observations for the test and training dataframes
print('Number of observations in the training data:', len(train))
print('Number of observations in the test data:',len(test))
# Out:
# Number of observations in the training data: 18680
# Number of observations in the test data: 4670

# %%
    #some parameters
    DO_LOWESS = False
    hyperopt = True
    # Run MLPRegressor with hyperopt optimization
    nn = HyperoptModel(train.copy(), test.copy(),'nn', cv=4, max_evals=100)
    features = list(df)
    features.remove('score')
    nn.raw_features = features

    nn.pipeline = Pipeline([
        ('estimate', MLPRegressor())
    ])
   
    nn.space = {
         'estimate__alpha' : hp.uniform('estimate__alpha', 0.001, 1),
         'estimate__activation' : hp.choice('estimate__activation', ['relu']), # 'identity', 'logistic', 'tanh', 'relu'
         #'estimate__learning_rate' : hp.choice('estimate__learning_rate', ['constant', 'invscaling', 'adaptive']),
         'estimate__hidden_layer_sizes' : scope.int(hp.uniform('estimate__hidden_layer_sizes', 1, 100)),
         'estimate__solver' : hp.choice('estimate__solver', ['adam']), #'lbfgs', 'sgd',
         #'estimate__max_iter' : scope.int(hp.uniform('estimate__max_iter', 500, 1000))
    }

    if hyperopt:
        nn.run(do_lowess=DO_LOWESS)
    else:
        # train with default params
        nn.pipeline.fit(X=nn.X_train, y=nn.y_train)
        nn.model = cat.pipeline
        nn.stats()
        nn.plot_predicted_vs_actual(do_lowess=DO_LOWESS)
        nn.plot_feature_importance()
        nn.qq_plot()
# Out:
# Performing parameters optimization...
# [1/100]	cv_eval_time=14.96 sec	RMSE=3.596778	R^2=-36976.682654
# [2/100]	cv_eval_time=12.09 sec	RMSE=3.398505	R^2=-42287.542880
# [3/100]	cv_eval_time=12.88 sec	RMSE=3.910157	R^2=-39306.220249
# [4/100]	cv_eval_time=23.88 sec	RMSE=1.108046	R^2=-13975.286206
# [5/100]	cv_eval_time=11.00 sec	RMSE=3.445665	R^2=-25653.944388
# [6/100]	cv_eval_time=10.88 sec	RMSE=3.108161	R^2=-35041.579666
# [7/100]	cv_eval_time=21.65 sec	RMSE=3.279743	R^2=-11439.305773
# [8/100]	cv_eval_time=13.54 sec	RMSE=3.952319	R^2=-17452.692564
# [9/100]	cv_eval_time=19.07 sec	RMSE=1.783315	R^2=-24052.838109
# [10/100]	cv_eval_time=9.92 sec	RMSE=6.289819	R^2=-29553.359435
# [11/100]	cv_eval_time=14.50 sec	RMSE=2.817205	R^2=-37110.203328
# [12/100]	cv_eval_time=19.07 sec	RMSE=2.680517	R^2=-33553.851378
# [13/100]	cv_eval_time=11.39 sec	RMSE=4.466425	R^2=-31282.216382
# [14/100]	cv_eval_time=14.31 sec	RMSE=3.865788	R^2=-23739.291739
# [15/100]	cv_eval_time=14.72 sec	RMSE=3.549600	R^2=-39772.713078
# [85/100]	cv_eval_time=28.65 sec	RMSE=0.802937	R^2=-6240.796018
# [86/100]	cv_eval_time=11.10 sec	RMSE=5.327073	R^2=-67452.439414
# [87/100]	cv_eval_time=21.58 sec	RMSE=1.710790	R^2=-11306.621225
# [88/100]	cv_eval_time=12.65 sec	RMSE=4.385662	R^2=-38446.795281
# [89/100]	cv_eval_time=26.54 sec	RMSE=1.127143	R^2=-10041.903050
# [90/100]	cv_eval_time=17.96 sec	RMSE=3.692915	R^2=-22587.774667
# [91/100]	cv_eval_time=22.45 sec	RMSE=2.381065	R^2=-22121.724151
# [92/100]	cv_eval_time=23.06 sec	RMSE=3.940255	R^2=-18224.767177
# [93/100]	cv_eval_time=13.85 sec	RMSE=2.860565	R^2=-61591.176695
# [94/100]	cv_eval_time=11.24 sec	RMSE=4.252222	R^2=-47130.499817
# [95/100]	cv_eval_time=10.60 sec	RMSE=4.126765	R^2=-35383.089770
# [96/100]	cv_eval_time=12.55 sec	RMSE=5.365051	R^2=-24768.746448
# [97/100]	cv_eval_time=19.12 sec	RMSE=2.958644	R^2=-18175.696212
# [98/100]	cv_eval_time=13.85 sec	RMSE=3.890951	R^2=-43777.657715
# [99/100]	cv_eval_time=23.59 sec	RMSE=2.119100	R^2=-8473.098600
# [100/100]	cv_eval_time=23.96 sec	RMSE=1.626292	R^2=-94.633444
#  elapsed time: 30min 41s
#
# Stats (train | test):
# 	R^2 score:		-0.3906
# 					-0.0012
# 	RMSE:			0.0234
# 					0.0168
# 	Mean error:		0.0069
# 					0.0064
#
# Best parameters set:
# {'estimate__activation': 'relu',
#  'estimate__alpha': 0.7128229380544131,
#  'estimate__hidden_layer_sizes': 1,
#  'estimate__solver': 'adam'}
#
# Plotting predicted vs. actual ...done
#
# Plotting QQ ...done

# %%
    #some parameters
    DO_LOWESS = False
    hyperopt = True
    # Run MLPRegressor with hyperopt optimization
    nn = HyperoptModel(train.copy(), test.copy(),'nn', cv=4, max_evals=100)
    features = list(df)
    features.remove('score')
    nn.raw_features = features

    nn.pipeline = Pipeline([
        ('estimate', MLPRegressor())
    ])
   
    nn.space = {
         'estimate__alpha' : hp.uniform('estimate__alpha', 0.001, 1),
         'estimate__activation' : hp.choice('estimate__activation', ['logistic']), # 'identity', 'logistic', 'tanh', 'relu'
         #'estimate__learning_rate' : hp.choice('estimate__learning_rate', ['constant', 'invscaling', 'adaptive']),
         'estimate__hidden_layer_sizes' : scope.int(hp.uniform('estimate__hidden_layer_sizes', 1, 100)),
         'estimate__solver' : hp.choice('estimate__solver', ['adam']), #'lbfgs', 'sgd',
         #'estimate__max_iter' : scope.int(hp.uniform('estimate__max_iter', 500, 1000))
    }

    if hyperopt:
        nn.run(do_lowess=DO_LOWESS)
    else:
        # train with default params
        nn.pipeline.fit(X=nn.X_train, y=nn.y_train)
        nn.model = cat.pipeline
        nn.stats()
        nn.plot_predicted_vs_actual(do_lowess=DO_LOWESS)
        nn.plot_feature_importance()
        nn.qq_plot()
# Out:
# Performing parameters optimization...
# [1/100]	cv_eval_time=8.03 sec	RMSE=0.020820	R^2=0.061477
# [2/100]	cv_eval_time=4.62 sec	RMSE=0.020939	R^2=-0.390575
# [3/100]	cv_eval_time=6.38 sec	RMSE=0.021674	R^2=-0.315084
# [4/100]	cv_eval_time=6.18 sec	RMSE=0.023253	R^2=-0.399631
# [5/100]	cv_eval_time=7.68 sec	RMSE=0.022916	R^2=-0.530148
# [6/100]	cv_eval_time=8.38 sec	RMSE=0.025560	R^2=-0.354913
# [7/100]	cv_eval_time=8.00 sec	RMSE=0.025867	R^2=-0.465996
# [8/100]	cv_eval_time=7.44 sec	RMSE=0.021679	R^2=-0.859510
# [9/100]	cv_eval_time=9.91 sec	RMSE=0.022158	R^2=-0.829357
# [10/100]	cv_eval_time=7.91 sec	RMSE=0.021416	R^2=-0.331188
# [11/100]	cv_eval_time=7.49 sec	RMSE=0.020143	R^2=0.047803
# [12/100]	cv_eval_time=5.28 sec	RMSE=0.032978	R^2=-1.152457
# [13/100]	cv_eval_time=8.33 sec	RMSE=0.019339	R^2=-0.107435
# [14/100]	cv_eval_time=5.54 sec	RMSE=0.021596	R^2=-0.550401
# [15/100]	cv_eval_time=2.66 sec	RMSE=0.024937	R^2=-0.206263
# [16/100]	cv_eval_time=5.26 sec	RMSE=0.026997	R^2=-0.830170
# [17/100]	cv_eval_time=8.72 sec	RMSE=0.020233	R^2=-0.011670
# [18/100]	cv_eval_time=10.42 sec	RMSE=0.019953	R^2=-0.161521
# [19/100]	cv_eval_time=8.36 sec	RMSE=0.020855	R^2=0.029242
# [20/100]	cv_eval_time=11.51 sec	RMSE=0.022298	R^2=-0.178239
# [21/100]	cv_eval_time=10.33 sec	RMSE=0.019253	R^2=-0.037696
# [22/100]	cv_eval_time=10.13 sec	RMSE=0.019525	R^2=-0.103923
# [23/100]	cv_eval_time=10.08 sec	RMSE=0.022656	R^2=0.052925
# [24/100]	cv_eval_time=9.71 sec	RMSE=0.019127	R^2=-0.170336
# [25/100]	cv_eval_time=11.06 sec	RMSE=0.019308	R^2=-0.039662
# [26/100]	cv_eval_time=10.66 sec	RMSE=0.020915	R^2=0.068515
# [27/100]	cv_eval_time=6.21 sec	RMSE=0.019674	R^2=-0.044711
# [28/100]	cv_eval_time=10.58 sec	RMSE=0.019855	R^2=0.067730
# [29/100]	cv_eval_time=9.57 sec	RMSE=0.019426	R^2=-0.043340
# [30/100]	cv_eval_time=10.42 sec	RMSE=0.019677	R^2=-0.172284
# [31/100]	cv_eval_time=8.40 sec	RMSE=0.019598	R^2=0.054385
# [32/100]	cv_eval_time=10.38 sec	RMSE=0.019621	R^2=-0.073053
# [33/100]	cv_eval_time=9.13 sec	RMSE=0.019380	R^2=0.079204
# [34/100]	cv_eval_time=4.92 sec	RMSE=0.022552	R^2=-0.613324
# [35/100]	cv_eval_time=7.27 sec	RMSE=0.020559	R^2=0.040987
# [36/100]	cv_eval_time=10.14 sec	RMSE=0.020771	R^2=-0.103821
# [37/100]	cv_eval_time=10.64 sec	RMSE=0.019880	R^2=-0.010876
# [38/100]	cv_eval_time=10.70 sec	RMSE=0.019315	R^2=-0.001325
# [39/100]	cv_eval_time=10.86 sec	RMSE=0.019478	R^2=0.004621
# [40/100]	cv_eval_time=8.32 sec	RMSE=0.020197	R^2=-0.297419
# [41/100]	cv_eval_time=8.33 sec	RMSE=0.020342	R^2=-0.000219
# [42/100]	cv_eval_time=5.19 sec	RMSE=0.031676	R^2=-0.980672
# [43/100]	cv_eval_time=7.18 sec	RMSE=0.019465	R^2=0.068018
# [44/100]	cv_eval_time=9.67 sec	RMSE=0.023706	R^2=-0.279371
# [45/100]	cv_eval_time=8.86 sec	RMSE=0.021167	R^2=0.034136
# [46/100]	cv_eval_time=8.19 sec	RMSE=0.020953	R^2=-0.250042
# [47/100]	cv_eval_time=10.22 sec	RMSE=0.020356	R^2=0.033523
# [48/100]	cv_eval_time=11.16 sec	RMSE=0.021404	R^2=-0.185607
# [49/100]	cv_eval_time=9.02 sec	RMSE=0.020408	R^2=-0.001592
# [50/100]	cv_eval_time=8.30 sec	RMSE=0.019700	R^2=0.072076
# [51/100]	cv_eval_time=11.63 sec	RMSE=0.019678	R^2=-0.045116
# [52/100]	cv_eval_time=9.90 sec	RMSE=0.020606	R^2=-0.248984
# [53/100]	cv_eval_time=7.21 sec	RMSE=0.023046	R^2=-0.134197
# [54/100]	cv_eval_time=7.94 sec	RMSE=0.019731	R^2=0.024135
# [55/100]	cv_eval_time=7.69 sec	RMSE=0.020219	R^2=-0.274155
# [56/100]	cv_eval_time=5.82 sec	RMSE=0.029772	R^2=-1.890983
# [57/100]	cv_eval_time=10.14 sec	RMSE=0.023555	R^2=-0.275225
# [58/100]	cv_eval_time=7.03 sec	RMSE=0.019931	R^2=-0.148165
# [59/100]	cv_eval_time=4.46 sec	RMSE=0.027015	R^2=-0.808134
# [60/100]	cv_eval_time=9.62 sec	RMSE=0.020294	R^2=-0.089882
# [61/100]	cv_eval_time=9.69 sec	RMSE=0.019993	R^2=-0.021175
# [62/100]	cv_eval_time=5.25 sec	RMSE=0.020998	R^2=-0.322597
# [63/100]	cv_eval_time=11.09 sec	RMSE=0.021228	R^2=-0.099776
# [64/100]	cv_eval_time=9.02 sec	RMSE=0.019344	R^2=0.034899
# [65/100]	cv_eval_time=9.58 sec	RMSE=0.019064	R^2=0.016736
# [66/100]	cv_eval_time=8.73 sec	RMSE=0.020303	R^2=-0.036416
# [67/100]	cv_eval_time=8.27 sec	RMSE=0.020176	R^2=-0.035980
# [68/100]	cv_eval_time=8.61 sec	RMSE=0.021618	R^2=0.043795
# [69/100]	cv_eval_time=9.42 sec	RMSE=0.019608	R^2=0.075224
# [70/100]	cv_eval_time=9.35 sec	RMSE=0.019234	R^2=0.060109
# [71/100]	cv_eval_time=10.38 sec	RMSE=0.019587	R^2=-0.089006
# [72/100]	cv_eval_time=9.72 sec	RMSE=0.019676	R^2=0.012712
# [73/100]	cv_eval_time=7.68 sec	RMSE=0.019542	R^2=0.068651
# [74/100]	cv_eval_time=8.69 sec	RMSE=0.019488	R^2=-0.023153
# [75/100]	cv_eval_time=7.01 sec	RMSE=0.020047	R^2=0.072637
# [76/100]	cv_eval_time=9.59 sec	RMSE=0.029386	R^2=-0.027901
# [77/100]	cv_eval_time=10.26 sec	RMSE=0.019572	R^2=-0.002502
# [78/100]	cv_eval_time=9.43 sec	RMSE=0.019711	R^2=-0.009585
# [79/100]	cv_eval_time=9.95 sec	RMSE=0.018876	R^2=-0.006194
# [80/100]	cv_eval_time=11.29 sec	RMSE=0.020619	R^2=-0.070240
# [81/100]	cv_eval_time=9.23 sec	RMSE=0.022914	R^2=-0.032367
# [82/100]	cv_eval_time=6.35 sec	RMSE=0.019671	R^2=0.049838
# [83/100]	cv_eval_time=10.15 sec	RMSE=0.020458	R^2=0.086604
# [84/100]	cv_eval_time=11.08 sec	RMSE=0.019614	R^2=-0.004809
# [85/100]	cv_eval_time=8.25 sec	RMSE=0.019320	R^2=-0.083464
# [86/100]	cv_eval_time=7.89 sec	RMSE=0.019611	R^2=0.009469
# [87/100]	cv_eval_time=5.68 sec	RMSE=0.022981	R^2=0.000512
# [88/100]	cv_eval_time=7.61 sec	RMSE=0.020104	R^2=-0.043313
# [89/100]	cv_eval_time=8.22 sec	RMSE=0.021181	R^2=-0.238437
# [90/100]	cv_eval_time=11.08 sec	RMSE=0.020590	R^2=0.039774
# [91/100]	cv_eval_time=11.34 sec	RMSE=0.020009	R^2=-0.022047
# [92/100]	cv_eval_time=10.79 sec	RMSE=0.021658	R^2=-0.027965
# [93/100]	cv_eval_time=11.39 sec	RMSE=0.021554	R^2=-0.105368
# [94/100]	cv_eval_time=12.10 sec	RMSE=0.019080	R^2=-0.115668
# [95/100]	cv_eval_time=6.65 sec	RMSE=0.019945	R^2=0.063458
# [96/100]	cv_eval_time=9.29 sec	RMSE=0.018944	R^2=0.040669
# [97/100]	cv_eval_time=7.95 sec	RMSE=0.020632	R^2=-0.147550
# [98/100]	cv_eval_time=8.78 sec	RMSE=0.019677	R^2=-0.086257
# [99/100]	cv_eval_time=10.31 sec	RMSE=0.019350	R^2=-0.049323
# [100/100]	cv_eval_time=10.14 sec	RMSE=0.021533	R^2=-0.151255
#  elapsed time: 14min 33s
#
# Stats (train | test):
# 	R^2 score:		0.1506
# 					0.1476
# 	RMSE:			0.0183
# 					0.0155
# 	Mean error:		0.0056
# 					0.0054
#
# Best parameters set:
# {'estimate__activation': 'logistic',
#  'estimate__alpha': 0.8712629786397766,
#  'estimate__hidden_layer_sizes': 79,
#  'estimate__solver': 'adam'}
#
# Plotting predicted vs. actual ...done
#
# Plotting QQ ...done
